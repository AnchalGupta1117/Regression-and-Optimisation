# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_excel(r"C:\Users\ANCHAL\Desktop\CODING\ML\LUNG CANCER DATASET.xlsx")
dataset
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         M   65        1               1        1              2
# 1         F   55        1               2        2              1
# 2         F   78        2               2        1              1
# 3         M   60        2               1        1              1
# 4         F   80        1               1        2              1
# ...     ...  ...      ...             ...      ...            ...
# 2995      F   71        2               1        1              2
# 2996      F   75        1               2        1              1
# 2997      F   62        2               2        2              1
# 2998      M   30        1               1        2              2
# 2999      M   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# 1                   1        2        2         2                  1
# 2                   1        2        1         2                  1
# 3                   2        1        2         1                  1
# 4                   1        2        1         2                  1
# ...               ...      ...      ...       ...                ...
# 2995                2        1        1         1                  1
# 2996                1        2        2         2                  2
# 2997                2        2        2         2                  1
# 2998                2        2        2         2                  2
# 2999                1        1        2         2                  2
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 0            2                    2                      2           1
# 1            1                    1                      2           2
# 2            1                    2                      1           1
# 3            2                    1                      2           2
# 4            1                    1                      1           2
# ...        ...                  ...                    ...         ...
# 2995         2                    1                      1           2
# 2996         1                    1                      2           1
# 2997         1                    2                      2           2
# 2998         1                    2                      1           2
# 2999         1                    1                      1           1
#
#      LUNG_CANCER
# 0             NO
# 1             NO
# 2            YES
# 3            YES
# 4             NO
# ...          ...
# 2995          NO
# 2996          NO
# 2997         YES
# 2998         YES
# 2999         YES
#
# [3000 rows x 16 columns]

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 1/3, random_state = 0)

# %%
print (X_train, y_train)
# Out:
# [['M' 79 2 ... 2 1 1]
#  ['M' 44 2 ... 1 1 1]
#  ['M' 73 1 ... 1 2 2]
#  ...
#  ['F' 33 1 ... 2 1 1]
#  ['M' 56 1 ... 1 1 1]
#  ['F' 69 2 ... 2 1 2]] ['NO' 'YES' 'NO' ... 'NO' 'YES' 'NO']

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
print (X_test, y_test)
# Out:
# [['F' 78 2 ... 1 2 1]
#  ['M' 48 2 ... 1 1 1]
#  ['M' 51 2 ... 1 2 1]
#  ...
#  ['M' 44 1 ... 2 1 2]
#  ['M' 53 1 ... 1 1 1]
#  ['M' 77 2 ... 2 1 1]] ['YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'YES' 'YES' 'NO' 'NO' 'NO'
#  'YES' 'YES' 'NO' 'YES' 'NO' 'NO' 'YES' 'YES' 'YES' 'NO' 'NO' 'YES' 'NO'
#  'NO' 'YES' 'YES' 'NO' 'NO' 'NO' 'YES' 'NO' 'NO' 'YES' 'YES' 'NO' 'YES'
#  'NO' 'NO' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO'
#  'NO' 'NO' 'NO' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'NO' 'NO' 'NO' 'NO' 'NO' 'YES' 'YES' 'YES' 'NO'
#  'YES' 'YES' 'YES' 'NO' 'NO' 'NO' 'YES' 'YES' 'NO' 'NO' 'YES' 'NO' 'NO'
#  'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO'
#  'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'NO' 'NO'
#  'YES' 'YES' 'NO' 'NO' 'NO' 'NO' 'YES' 'NO' 'YES' 'NO' 'NO' 'NO' 'NO'
#  'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'NO' 'NO' 'NO' 'YES' 'NO' 'NO' 'YES'
#  'YES' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'YES' 'YES'
#  'YES' 'NO' 'NO' 'YES' 'YES' 'YES' 'YES' 'NO' 'NO' 'NO' 'YES' 'YES' 'NO'
#  'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'NO' 'NO' 'YES' 'YES' 'YES' 'NO' 'YES'
#  'YES' 'YES' 'NO' 'NO' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'NO'
#  'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'NO' 'YES' 'NO' 'YES' 'NO' 'NO' 'YES'
#  'YES' 'NO' 'NO' 'NO' 'NO' 'YES' 'YES' 'NO' 'NO' 'NO' 'YES' 'YES' 'YES'
#  'YES' 'NO' 'NO' 'NO' 'NO' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'NO' 'NO' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'NO' 'NO' 'YES' 'YES'
#  'YES' 'NO' 'YES' 'NO' 'NO' 'NO' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'NO' 'NO' 'NO' 'YES' 'NO' 'YES' 'NO' 'NO' 'NO' 'NO'
#  'NO' 'NO' 'NO' 'NO' 'YES' 'NO' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES'
#  'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'YES' 'NO' 'NO' 'NO' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'NO' 'NO' 'YES' 'NO' 'YES' 'NO' 'YES' 'NO' 'YES' 'YES'
#  'NO' 'NO' 'NO' 'YES' 'YES' 'NO' 'NO' 'YES' 'NO' 'YES' 'YES' 'NO' 'YES'
#  'YES' 'NO' 'YES' 'NO' 'NO' 'YES' 'YES' 'NO' 'NO' 'NO' 'YES' 'NO' 'NO'
#  'NO' 'YES' 'YES' 'YES' 'NO' 'NO' 'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'NO'
#  'YES' 'NO' 'YES' 'YES' 'YES' 'NO' 'NO' 'YES' 'YES' 'NO' 'NO' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'NO' 'NO' 'NO' 'YES' 'YES' 'YES' 'YES'
#  'NO' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'NO' 'YES' 'YES' 'YES' 'YES' 'NO'
#  'YES' 'NO' 'NO' 'YES' 'YES' 'YES' 'NO' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES'
#  'NO' 'NO' 'NO' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'NO'
#  'YES' 'YES' 'NO' 'NO' 'NO' 'NO' 'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO'
#  'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'NO' 'NO' 'YES' 'YES' 'NO'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'NO' 'NO' 'YES' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'YES'
#  'NO' 'YES' 'YES' 'YES' 'YES' 'NO' 'NO' 'NO' 'NO' 'YES' 'YES' 'YES' 'NO'
#  'NO' 'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'NO' 'NO' 'YES' 'YES'
#  'YES' 'NO' 'NO' 'YES' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'YES' 'NO' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'NO' 'NO' 'YES' 'NO' 'NO'
#  'NO' 'NO' 'YES' 'YES' 'NO' 'NO' 'NO' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES'
#  'NO' 'NO' 'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO'
#  'NO' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'NO' 'YES' 'NO' 'NO' 'YES' 'YES'
#  'NO' 'YES' 'NO' 'YES' 'YES' 'NO' 'NO' 'YES' 'YES' 'NO' 'NO' 'NO' 'NO'
#  'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'NO' 'NO' 'NO' 'YES' 'YES' 'NO'
#  'YES' 'YES' 'YES' 'NO' 'NO' 'NO' 'NO' 'YES' 'YES' 'YES' 'NO' 'YES' 'NO'
#  'YES' 'NO' 'NO' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'NO' 'NO' 'YES' 'YES'
#  'NO' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'NO'
#  'NO' 'YES' 'NO' 'NO' 'NO' 'YES' 'NO' 'YES' 'NO' 'YES' 'YES' 'YES' 'NO'
#  'NO' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES'
#  'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'NO' 'YES'
#  'YES' 'YES' 'NO' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'NO' 'NO'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'NO' 'YES' 'NO'
#  'YES' 'NO' 'NO' 'YES' 'YES' 'NO' 'NO' 'NO' 'NO' 'YES' 'NO' 'NO' 'YES'
#  'YES' 'NO' 'NO' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'NO' 'NO'
#  'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'NO' 'YES' 'NO' 'YES' 'YES' 'YES' 'NO'
#  'YES' 'NO' 'YES' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'YES' 'NO' 'NO'
#  'NO' 'YES' 'NO' 'NO' 'YES' 'YES' 'NO' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO'
#  'NO' 'YES' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'NO' 'NO' 'NO'
#  'YES' 'NO' 'YES' 'NO' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES'
#  'NO' 'YES' 'YES' 'YES' 'YES' 'NO' 'NO' 'NO' 'YES' 'YES' 'NO' 'NO' 'NO'
#  'NO' 'NO' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'YES' 'NO' 'YES' 'NO' 'NO'
#  'NO' 'NO' 'YES' 'YES' 'NO' 'NO' 'NO' 'NO' 'NO' 'YES' 'NO' 'NO' 'YES'
#  'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'NO' 'NO' 'NO' 'NO' 'NO' 'YES' 'NO' 'NO' 'YES' 'NO' 'NO' 'NO' 'NO'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'NO' 'YES' 'NO' 'YES' 'NO' 'YES'
#  'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'YES' 'YES' 'NO' 'NO' 'NO' 'YES'
#  'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'NO'
#  'YES' 'NO' 'YES' 'YES' 'YES' 'NO' 'NO' 'YES' 'NO' 'NO' 'NO' 'NO' 'NO'
#  'YES' 'YES' 'NO' 'YES' 'NO' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'NO' 'NO'
#  'NO' 'NO' 'YES' 'NO' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'NO' 'YES' 'YES' 'YES' 'NO' 'NO' 'YES' 'YES' 'YES' 'NO' 'YES' 'NO' 'YES'
#  'NO' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'NO' 'NO'
#  'NO' 'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'NO' 'NO' 'YES' 'YES' 'NO' 'NO'
#  'NO' 'YES' 'YES' 'NO' 'NO' 'NO' 'YES' 'NO' 'YES' 'YES' 'NO' 'NO' 'YES'
#  'NO' 'YES' 'YES' 'NO' 'YES' 'NO' 'NO' 'YES' 'NO' 'YES']

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the 'Gender' column
dataset['GENDER'] = dataset['GENDER'].replace({'M': 1, 'F': 0})

# %%
dataset['LUNG_CANCER'] = dataset['LUNG_CANCER'].replace({'NO': 0, 'YES': 1})

# %%
print(dataset)
# Out:
#       GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0          1   65        1               1        1              2
# 1          0   55        1               2        2              1
# 2          0   78        2               2        1              1
# 3          1   60        2               1        1              1
# 4          0   80        1               1        2              1
# ...      ...  ...      ...             ...      ...            ...
# 2995       0   71        2               1        1              2
# 2996       0   75        1               2        1              1
# 2997       0   62        2               2        2              1
# 2998       1   30        1               1        2              2
# 2999       1   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# 1                   1        2        2         2                  1
# 2                   1        2        1         2                  1
# 3                   2        1        2         1                  1
# 4                   1        2        1         2                  1
# ...               ...      ...      ...       ...                ...
# 2995                2        1        1         1                  1
# 2996                1        2        2         2                  2
# 2997                2        2        2         2                  1
# 2998                2        2        2         2                  2
# 2999                1        1        2         2                  2
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 0            2                    2                      2           1
# 1            1                    1                      2           2
# 2            1                    2                      1           1
# 3            2                    1                      2           2
# 4            1                    1                      1           2
# ...        ...                  ...                    ...         ...
# 2995         2                    1                      1           2
# 2996         1                    1                      2           1
# 2997         1                    2                      2           2
# 2998         1                    2                      1           2
# 2999         1                    1                      1           1
#
#       LUNG_CANCER
# 0               0
# 1               0
# 2               1
# 3               1
# 4               0
# ...           ...
# 2995            0
# 2996            0
# 2997            1
# 2998            1
# 2999            1
#
# [3000 rows x 16 columns]

# %%
#dataset = dataset[~dataset['LUNG_CANCER_encoded'].isin(['0', '1'])]

# %%
#dataset = dataset[~dataset['GENDER_encoded'].isin(['0', '1'])]

# %%
print(dataset)
# Out:
#       GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0          1   65        1               1        1              2
# 1          0   55        1               2        2              1
# 2          0   78        2               2        1              1
# 3          1   60        2               1        1              1
# 4          0   80        1               1        2              1
# ...      ...  ...      ...             ...      ...            ...
# 2995       0   71        2               1        1              2
# 2996       0   75        1               2        1              1
# 2997       0   62        2               2        2              1
# 2998       1   30        1               1        2              2
# 2999       1   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# 1                   1        2        2         2                  1
# 2                   1        2        1         2                  1
# 3                   2        1        2         1                  1
# 4                   1        2        1         2                  1
# ...               ...      ...      ...       ...                ...
# 2995                2        1        1         1                  1
# 2996                1        2        2         2                  2
# 2997                2        2        2         2                  1
# 2998                2        2        2         2                  2
# 2999                1        1        2         2                  2
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 0            2                    2                      2           1
# 1            1                    1                      2           2
# 2            1                    2                      1           1
# 3            2                    1                      2           2
# 4            1                    1                      1           2
# ...        ...                  ...                    ...         ...
# 2995         2                    1                      1           2
# 2996         1                    1                      2           1
# 2997         1                    2                      2           2
# 2998         1                    2                      1           2
# 2999         1                    1                      1           1
#
#       LUNG_CANCER
# 0               0
# 1               0
# 2               1
# 3               1
# 4               0
# ...           ...
# 2995            0
# 2996            0
# 2997            1
# 2998            1
# 2999            1
#
# [3000 rows x 16 columns]

# %%
unique_genders = dataset['GENDER'].unique()
print(unique_genders)
dataset['GENDER'] = dataset['GENDER'].replace('Unknown', pd.NA)
print(dataset)
valid_genders = ['F', 'M']

def clean_gender(GENDER):
    if GENDER not in valid_GENDER:
        return pd.NA  # Replace invalid entry with NaN
    return GENDER

dataset['GENDER'] = dataset['GENDER'].apply(clean_gender)
print(dataset)
dataset_cleaned = dataset.dropna(subset=['GENDER'])
print(dataset_cleaned)
# Out:
# [1 0]
#       GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0          1   65        1               1        1              2
# 1          0   55        1               2        2              1
# 2          0   78        2               2        1              1
# 3          1   60        2               1        1              1
# 4          0   80        1               1        2              1
# ...      ...  ...      ...             ...      ...            ...
# 2995       0   71        2               1        1              2
# 2996       0   75        1               2        1              1
# 2997       0   62        2               2        2              1
# 2998       1   30        1               1        2              2
# 2999       1   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# 1                   1        2        2         2                  1
# 2                   1        2        1         2                  1
# 3                   2        1        2         1                  1
# 4                   1        2        1         2                  1
# ...               ...      ...      ...       ...                ...
# 2995                2        1        1         1                  1
# 2996                1        2        2         2                  2
# 2997                2        2        2         2                  1
# 2998                2        2        2         2                  2
# 2999                1        1        2         2                  2
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 0            2                    2                      2           1
# 1            1                    1                      2           2
# 2            1                    2                      1           1
# 3            2                    1                      2           2
# 4            1                    1                      1           2
# ...        ...                  ...                    ...         ...
# 2995         2                    1                      1           2
# 2996         1                    1                      2           1
# 2997         1                    2                      2           2
# 2998         1                    2                      1           2
# 2999         1                    1                      1           1
#
#       LUNG_CANCER
# 0               0
# 1               0
# 2               1
# 3               1
# 4               0
# ...           ...
# 2995            0
# 2996            0
# 2997            1
# 2998            1
# 2999            1
#
# [3000 rows x 16 columns]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[151], line 12
#       9         return pd.NA  # Replace invalid entry with NaN
#      10     return GENDER
# ---> 12 dataset['GENDER'] = dataset['GENDER'].apply(clean_gender)
#      13 print(dataset)
#      14 dataset_cleaned = dataset.dropna(subset=['GENDER'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1209, in SeriesApply.apply(self)
#    1206     return self.apply_compat()
#    1208 # self.func is Callable
# -> 1209 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1289, in SeriesApply.apply_standard(self)
#    1283 # row-wise access
#    1284 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1285 # we need to give `na_action="ignore"` for categorical data.
#    1286 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1287 #  Categorical (GH51645).
#    1288 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1289 mapped = obj._map_values(
#    1290     mapper=curried, na_action=action, convert=self.convert_dtype
#    1291 )
#    1293 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1294     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1295     #  See also GH#25959 regarding EA support
#    1296     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2926, in pandas._libs.lib.map_infer()
#
# Cell In[151], line 8, in clean_gender(GENDER)
#       7 def clean_gender(GENDER):
# ----> 8     if GENDER not in valid_GENDER:
#       9         return pd.NA  # Replace invalid entry with NaN
#      10     return GENDER
#
# NameError: name 'valid_GENDER' is not defined

# %%
try:
    dataset['GENDER'] = dataset['GENDER'].astype(float)
    dataset['AGE'] = dataset['AGE'].astype(float)
    dataset['LUNG_CANCER'] = dataset['LUNG_CANCER'].astype(float)
except ValueError as e:
    print(f"ValueError: {e}")
    # Handle the error or clean the data
    # For example, replace 'M' with NaN (Not a Number)
    dataset['GENDER'] = pd.to_numeric(dataset['GENDER'], errors='coerce')
    dataset['AGE'] = pd.to_numeric(dataset['AGE'], errors='coerce')
    dataset['LUNG_CANCER'] = pd.to_numeric(dataset['LUNG_CANCER'], errors='coerce')
print(dataset)
# Out:
#       GENDER   AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        1.0  65.0        1               1        1              2
# 1        0.0  55.0        1               2        2              1
# 2        0.0  78.0        2               2        1              1
# 3        1.0  60.0        2               1        1              1
# 4        0.0  80.0        1               1        2              1
# ...      ...   ...      ...             ...      ...            ...
# 2995     0.0  71.0        2               1        1              2
# 2996     0.0  75.0        1               2        1              1
# 2997     0.0  62.0        2               2        2              1
# 2998     1.0  30.0        1               1        2              2
# 2999     1.0  40.0        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# 1                   1        2        2         2                  1
# 2                   1        2        1         2                  1
# 3                   2        1        2         1                  1
# 4                   1        2        1         2                  1
# ...               ...      ...      ...       ...                ...
# 2995                2        1        1         1                  1
# 2996                1        2        2         2                  2
# 2997                2        2        2         2                  1
# 2998                2        2        2         2                  2
# 2999                1        1        2         2                  2
#
#       COUGHING  SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  \
# 0            2                    2                      2           1
# 1            1                    1                      2           2
# 2            1                    2                      1           1
# 3            2                    1                      2           2
# 4            1                    1                      1           2
# ...        ...                  ...                    ...         ...
# 2995         2                    1                      1           2
# 2996         1                    1                      2           1
# 2997         1                    2                      2           2
# 2998         1                    2                      1           2
# 2999         1                    1                      1           1
#
#       LUNG_CANCER
# 0             0.0
# 1             0.0
# 2             1.0
# 3             1.0
# 4             0.0
# ...           ...
# 2995          0.0
# 2996          0.0
# 2997          1.0
# 2998          1.0
# 2999          1.0
#
# [3000 rows x 16 columns]

# %%
regressor.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[153], line 1
# ----> 1 regressor.fit(X_train, Y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
#     661     sample_weight=sample_weight,
#     662 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:584, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     582         y = check_array(y, input_name="y", **check_y_params)
#     583     else:
# --> 584         X, y = check_X_y(X, y, **check_params)
#     585     out = X, y
#     587 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1106, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1101         estimator_name = _check_estimator_name(estimator)
#    1102     raise ValueError(
#    1103         f"{estimator_name} requires y to be passed, but the target y is None"
#    1104     )
# -> 1106 X = check_array(
#    1107     X,
#    1108     accept_sparse=accept_sparse,
#    1109     accept_large_sparse=accept_large_sparse,
#    1110     dtype=dtype,
#    1111     order=order,
#    1112     copy=copy,
#    1113     force_all_finite=force_all_finite,
#    1114     ensure_2d=ensure_2d,
#    1115     allow_nd=allow_nd,
#    1116     ensure_min_samples=ensure_min_samples,
#    1117     ensure_min_features=ensure_min_features,
#    1118     estimator=estimator,
#    1119     input_name="X",
#    1120 )
#    1122 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1124 check_consistent_length(X, y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877         array = xp.astype(array, dtype, copy=False)
#     878     else:
# --> 879         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880 except ComplexWarning as complex_warning:
#     881     raise ValueError(
#     882         "Complex data not supported\n{}\n".format(array)
#     883     ) from complex_warning
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# ValueError: could not convert string to float: 'M'
